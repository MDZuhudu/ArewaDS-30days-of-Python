# %% [markdown]
# # Exercises: Day 19
# ## Exercises: Level 1

# %%
#Write a function which count number of lines and number of words in a text. All the files are in the data the folder: a) Read obama_speech.txt file and 
#count number of lines and words b) Read michelle_obama_speech.txt file and count number of lines and words c) Read donald_speech.txt file and count number
#of lines and words d) Read melina_trump_speech.txt file and count number of lines and words

import re
import json
import csv
def count_words_lines(file):
    with open(file) as f:
        lines = f.readlines()
        words = []
        for line in lines:
            line = re.sub(r'[^\w\s]','',line)
            words.extend(line.split())
    print(f'Number of  lines: {len(lines)} and Number of  words: {len(words)}')


count_words_lines('obama_speech.txt')
count_words_lines('donald_speech.txt')
count_words_lines('michelle_obama_speech.txt')
count_words_lines('melina_trump_speech.txt')
# Out:
# Number of  lines: 66 and Number of  words: 2377
# Number of  lines: 48 and Number of  words: 1245
# Number of  lines: 83 and Number of  words: 2161
# Number of  lines: 33 and Number of  words: 1366

# %%
#Read the countries_data.json data file in data directory, create a function that finds the ten most spoken languages

import re
def most_spoken_languages(file_b,b):
    with open(file_b) as fb:
        list = json.loads(fb.read()) 
    languages = []
    for i in range(len(list)):
        languages.extend(list[i]['languages'])
    lang = {}
    for language in languages:
        lang[language] = lang.get(language,0) + 1
    sorted_lang = sorted(lang.items(), key= lambda x:x[1],reverse=True)
    result = [{item[1],item[0]} for item in sorted_lang]
    return result[:b]
print(most_spoken_languages('countries_data.json',10))
reslt = most_spoken_languages('countries_data.json',3)
print('\n', reslt,'\n')
# Out:
# [{'English', 91}, {'French', 45}, {25, 'Arabic'}, {24, 'Spanish'}, {9, 'Portuguese'}, {9, 'Russian'}, {8, 'Dutch'}, {'German', 7}, {'Chinese', 5}, {4, 'Serbian'}]
#
#  [{'English', 91}, {'French', 45}, {25, 'Arabic'}]

# %%
#Read the countries_data.json data file in data directory, create a function that creates a list of the ten most populated countries

def most_populated_countries(filename,n):
    with open(filename) as f:
        dic_list = json.loads(f.read())
    population = dict()
    for i in range(len(dic_list)):
        keys = dic_list[i]['name']
        values = dic_list[i]['population']
        population[keys] = values
    sorted_lt = sorted(population.items(), key= lambda x:x[1],reverse=True)
    final_list = [{'country':item[0],'population':item[1]} for item in sorted_lt]
    return final_list[:n]
print(most_populated_countries('countries_data.json',10))
most_populated_countries('countries_data.json',3)
# Out:
# [{'country': 'China', 'population': 1377422166}, {'country': 'India', 'population': 1295210000}, {'country': 'United States of America', 'population': 323947000}, {'country': 'Indonesia', 'population': 258705000}, {'country': 'Brazil', 'population': 206135893}, {'country': 'Pakistan', 'population': 194125062}, {'country': 'Nigeria', 'population': 186988000}, {'country': 'Bangladesh', 'population': 161006790}, {'country': 'Russian Federation', 'population': 146599183}, {'country': 'Japan', 'population': 126960000}]
# [{'country': 'China', 'population': 1377422166},
#  {'country': 'India', 'population': 1295210000},
#  {'country': 'United States of America', 'population': 323947000}]

# %% [markdown]
# # Exercises: Level 2

# %%
#Extract all incoming email addresses as a list from the email_exchange_big.txt file.

import re
with open('email_exchanges_big.txt') as f:
    lines = f.readlines()
email_addresses = []
for line in lines:
    email_addresses.extend(re.findall('[a-zA-Z0-9]*@[a-zA-Z]', line))
email_addresses[:]
# Out:
# ['marquard@u',
#  'postmaster@c',
#  'm05ECIaH010327@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'marquard@u',
#  'source@c',
#  'marquard@u',
#  'marquard@u',
#  'louis@m',
#  'postmaster@c',
#  'm04N8v6O008125@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'louis@m',
#  'source@c',
#  'louis@m',
#  'louis@m',
#  'zqian@u',
#  'postmaster@c',
#  'm04L92hb007923@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'rjlowe@i',
#  'postmaster@c',
#  'm04Kiem3007881@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'zqian@u',
#  'postmaster@c',
#  'm04K1cO0007738@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'zqian@u',
#  'rjlowe@i',
#  'postmaster@c',
#  'm04JmdwO007705@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'cwen@i',
#  'postmaster@c',
#  'm04GZQGZ007313@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'hu2@i',
#  'cwen@i',
#  'postmaster@c',
#  'm04GX6eG007292@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'hu2@i',
#  'gsilver@u',
#  'postmaster@c',
#  'm04GB1Lb007221@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'gsilver@u',
#  'postmaster@c',
#  'm04GA5KP007209@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'zqian@u',
#  'postmaster@c',
#  'm04G9EuX007197@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'gsilver@u',
#  'postmaster@c',
#  'm04G8d7w007184@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'wagnermr@i',
#  'postmaster@c',
#  'm04Fb6Ci007092@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'wagnermr@i',
#  'source@c',
#  'wagnermr@i',
#  'wagnermr@i',
#  'zqian@u',
#  'postmaster@c',
#  'm04FFv42007050@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'antranig@c',
#  'postmaster@c',
#  'm04F21Jo007031@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'antranig@c',
#  'source@c',
#  'antranig@c',
#  'antranig@c',
#  'ramasammycook@g',
#  'postmaster@c',
#  'm04E3psW006926@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ramasammycook@g',
#  'source@c',
#  'ramasammycook@g',
#  'ramasammycook@g',
#  'horwitz@u',
#  'postmaster@c',
#  'm04C0gfK006793@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'horwitz@u',
#  'source@c',
#  'horwitz@u',
#  'horwitz@u',
#  'horwitz@u',
#  'dhorwitz@d',
#  'dhorwitz@d',
#  'horwitz@u',
#  'postmaster@c',
#  'm04B6lK3006677@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'horwitz@u',
#  'source@c',
#  'horwitz@u',
#  'horwitz@u',
#  'horwitz@u',
#  'postmaster@c',
#  'm049lUxo006517@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'horwitz@u',
#  'source@c',
#  'horwitz@u',
#  'horwitz@u',
#  'josrodri@i',
#  'dhorwitz@d',
#  'horwitz@u',
#  'postmaster@c',
#  'm049W2i5006493@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'horwitz@u',
#  'source@c',
#  'horwitz@u',
#  'horwitz@u',
#  'josrodri@i',
#  'dhorwitz@d',
#  'marquard@u',
#  'postmaster@c',
#  'm0495rWB006420@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'marquard@u',
#  'source@c',
#  'marquard@u',
#  'marquard@u',
#  'louis@m',
#  'postmaster@c',
#  'm040NpCc005473@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'louis@m',
#  'source@c',
#  'louis@m',
#  'louis@m',
#  'louis@m',
#  'postmaster@c',
#  'm03MGhDa005292@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'louis@m',
#  'source@c',
#  'louis@m',
#  'louis@m',
#  'ray@m',
#  'postmaster@c',
#  'm03M5Ea7005273@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ray@m',
#  'source@c',
#  'ray@m',
#  'ray@m',
#  'cwen@i',
#  'postmaster@c',
#  'm03LX3gG005191@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'postmaster@c',
#  'm03LRUqH005177@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'wagnermr@i',
#  'cwen@i',
#  'postmaster@c',
#  'm03LMFo4005148@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'wagnermr@i',
#  'ray@m',
#  'postmaster@c',
#  'm03KsIIF005054@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ray@m',
#  'source@c',
#  'ray@m',
#  'ray@m',
#  'cwen@i',
#  'postmaster@c',
#  'm03KqOsp005029@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'zqian@u',
#  'postmaster@c',
#  'm03KPvQi004928@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'cwen@i',
#  'postmaster@c',
#  'm03KOBAp004915@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'wagnermr@i',
#  'rjlowe@i',
#  'zqian@u',
#  'postmaster@c',
#  'm03KMFfc004903@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03JUkCZ004841@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03InajQ004753@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'mmmay@i',
#  'postmaster@c',
#  'm03IbPY7004727@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'mmmay@i',
#  'source@c',
#  'mmmay@i',
#  'mmmay@i',
#  'wagnermr@i',
#  'cwen@i',
#  'postmaster@c',
#  'm03IJA7j004645@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'cwen@i',
#  'zqian@u',
#  'postmaster@c',
#  'm03IFbue004618@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03ICrFH004606@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03I7eg2004582@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'cwen@i',
#  'postmaster@c',
#  'm03I6g8Y004558@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'zqian@u',
#  'postmaster@c',
#  'm03I6pEt004570@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'cwen@i',
#  'postmaster@c',
#  'm03I4lVU004546@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'ray@m',
#  'postmaster@c',
#  'm03HlB1h004532@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ray@m',
#  'source@c',
#  'ray@m',
#  'ray@m',
#  'zqian@u',
#  'postmaster@c',
#  'm03HUeEg004479@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03HQUQ6004462@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03HNIp2004441@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'cwen@i',
#  'postmaster@c',
#  'm03Gh1r2004386@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'cwen@i',
#  'source@c',
#  'cwen@i',
#  'cwen@i',
#  'zqian@u',
#  'postmaster@c',
#  'm03GR5UM004357@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'ramasammycook@g',
#  'postmaster@c',
#  'm03GAkl3004326@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ramasammycook@g',
#  'source@c',
#  'ramasammycook@g',
#  'ramasammycook@g',
#  'gsilver@u',
#  'postmaster@c',
#  'm03FSpXg004260@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'gsilver@u',
#  'postmaster@c',
#  'm03FQhmF004248@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'freeman@e',
#  'postmaster@c',
#  'm03FLXtP004230@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'freeman@e',
#  'source@c',
#  'freeman@e',
#  'freeman@e',
#  'stuart@m',
#  'stuart@m',
#  'horwitz@u',
#  'stuart@m',
#  'stuart@m',
#  'horwitz@u',
#  'stuart@m',
#  'stuart@m',
#  'horwitz@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03FJsfm004218@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'gsilver@u',
#  'postmaster@c',
#  'm03F6Ctn004182@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'gsilver@u',
#  'postmaster@c',
#  'm03F534R004169@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'gsilver@u',
#  'postmaster@c',
#  'm03F3cRt004144@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'gsilver@u',
#  'source@c',
#  'gsilver@u',
#  'gsilver@u',
#  'zqian@u',
#  'postmaster@c',
#  'm03F11ZP004123@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'wagnermr@i',
#  'postmaster@c',
#  'm03ETqAT004022@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'wagnermr@i',
#  'source@c',
#  'wagnermr@i',
#  'wagnermr@i',
#  'freeman@e',
#  'postmaster@c',
#  'm03ENc58004008@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'freeman@e',
#  'source@c',
#  'freeman@e',
#  'freeman@e',
#  'stuart@m',
#  'stuart@m',
#  'stuart@m',
#  'stuart@m',
#  'cwen@i',
#  'tnguyen@i',
#  'postmaster@c',
#  'm03EKxOB003996@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'tnguyen@i',
#  'source@c',
#  'tnguyen@i',
#  'tnguyen@i',
#  'freeman@e',
#  'postmaster@c',
#  'm03EEOKY003968@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'freeman@e',
#  'source@c',
#  'freeman@e',
#  'freeman@e',
#  'stuart@m',
#  'stuart@m',
#  'cwen@i',
#  'stuart@m',
#  'stuart@m',
#  'wagnermr@i',
#  'cwen@i',
#  'wagnermr@i',
#  'postmaster@c',
#  'm03ECEFD003956@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'wagnermr@i',
#  'source@c',
#  'wagnermr@i',
#  'wagnermr@i',
#  'ramasammycook@g',
#  'postmaster@c',
#  'm03DgeVK003283@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ramasammycook@g',
#  'source@c',
#  'ramasammycook@g',
#  'ramasammycook@g',
#  'ray@m',
#  'postmaster@c',
#  'm02NjcHH001850@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ray@m',
#  'source@c',
#  'ray@m',
#  'ray@m',
#  'ray@m',
#  'postmaster@c',
#  'm02N8fmL001796@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'ray@m',
#  'source@c',
#  'ray@m',
#  'ray@m',
#  'zqian@u',
#  'postmaster@c',
#  'm02M3QKD001687@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'wagnermr@i',
#  'postmaster@c',
#  'm02M15vH001675@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'wagnermr@i',
#  'source@c',
#  'wagnermr@i',
#  'wagnermr@i',
#  'freeman@e',
#  'postmaster@c',
#  'm02LxOsg001648@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'freeman@e',
#  'source@c',
#  'freeman@e',
#  'freeman@e',
#  'stuart@m',
#  'stuart@m',
#  'ryan@a',
#  'chmaurer@i',
#  'postmaster@c',
#  'm02LrhrH001632@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'chmaurer@i',
#  'source@c',
#  'chmaurer@i',
#  'chmaurer@i',
#  'freeman@e',
#  'postmaster@c',
#  'm02LqN8o001620@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'freeman@e',
#  'source@c',
#  'freeman@e',
#  'freeman@e',
#  'stuart@m',
#  'stuart@m',
#  'kimsooil@b',
#  'stuart@m',
#  'stuart@m',
#  'ian@c',
#  'rjlowe@i',
#  'postmaster@c',
#  'm02KoD1g001526@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'zqian@u',
#  'postmaster@c',
#  'm02KQLMk001504@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'rjlowe@i',
#  'postmaster@c',
#  'm02KIxMC001487@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'rjlowe@i',
#  'postmaster@c',
#  'm02JY7iK001434@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'zqian@u',
#  'postmaster@c',
#  'm02HtJKE001310@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'zqian@u',
#  'source@c',
#  'zqian@u',
#  'zqian@u',
#  'rjlowe@i',
#  'postmaster@c',
#  'm02Hqk8q001298@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'rjlowe@i',
#  'postmaster@c',
#  'm02GC0dc001119@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'rjlowe@i',
#  'postmaster@c',
#  'm02G85Mp001097@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'rjlowe@i',
#  'source@c',
#  'rjlowe@i',
#  'rjlowe@i',
#  'horwitz@u',
#  'postmaster@c',
#  'm02Eqwdg001017@n',
#  'source@c',
#  'source@c',
#  'source@c',
#  'apache@l',
#  'source@c',
#  'horwitz@u',
#  'source@c',
#  'horwitz@u',
#  ...]

# %%
#Find the most common words in the English language. Call the name of your function find_most_common_words, it will take two parameters - a string or a file
#and a positive integer, indicating the number of words. Your function will return an array of tuples in descending order. Check the output

def find_most_common_words(file,n=10):
    '''
    Returns a list of tuples showing the count of the n most common words in the document, file
    '''
    with open(file) as f:
        lines = f.readlines()
    words = []
    for line in lines:
        # removing all characters that are not whitespace or alphanumeric using regex
        line = re.sub(r'[^\w\s]','',line)
        words.extend(line.split())
    words_dict = {}
    for word in words:
        words_dict[word] = words_dict.get(word,0) + 1
    words_sorted = sorted(words_dict.items(),key=lambda x:x[1],reverse=True)
    result = [(word[1],word[0]) for word in words_sorted]
    return result[:n]

find_most_common_words('donald_speech.txt',5)
# Out:
# [(61, 'the'), (53, 'and'), (40, 'will'), (38, 'of'), (32, 'to')]

# %%
#Use the function, find_most_frequent_words to find: a) The ten most frequent words used in Obama's speech b) The ten most frequent words used in Michelle's
#speech c) The ten most frequent words used in Trump's speech d) The ten most frequent words used in Melina's speech

print('Obama: ',find_most_common_words('obama_speech.txt')) 
# The ten most frequent words used in Michelle's speech 
print('Michelle Obama: ',find_most_common_words('michelle_obama_speech.txt'))
# The ten most frequent words used in Trump's speech 
print('Donald Trump: ',find_most_common_words('donald_speech.txt'))
# The ten most frequent words used in Melina's speech
print('Melania Trump: ',find_most_common_words('melina_trump_speech.txt'))
# Out:
# Obama:  [(120, 'the'), (107, 'and'), (81, 'of'), (66, 'to'), (58, 'our'), (50, 'we'), (48, 'a'), (47, 'that'), (36, 'is'), (23, 'us')]
# Michelle Obama:  [(84, 'to'), (80, 'and'), (78, 'the'), (46, 'of'), (41, 'a'), (40, 'that'), (36, 'in'), (27, 'for'), (27, 'our'), (26, 'my')]
# Donald Trump:  [(61, 'the'), (53, 'and'), (40, 'will'), (38, 'of'), (32, 'to'), (30, 'our'), (26, 'we'), (20, 'is'), (16, 'America'), (15, 'We')]
# Melania Trump:  [(73, 'and'), (54, 'to'), (48, 'the'), (29, 'is'), (28, 'I'), (27, 'for'), (25, 'of'), (22, 'a'), (19, 'that'), (18, 'you')]

# %%
'''Write a python application that checks similarity between two texts. It takes a file or a string as a parameter and it will evaluate the similarity of the
two texts. For instance check the similarity between the transcripts of Michelle's and Melina's speech. You may need a couple of functions, function to 
clean the text(clean_text), function to remove support words(remove_support_words) and finally to check the similarity(check_text_similarity). List of stop
words are in the data directory'''

def clean_text(file):
    '''
    Returns all the words in a text after removing the punctuations and others
    '''
    with open(file) as f:
        lines = f.readlines()
        words = []
        for line in lines:
            # removing all characters that are not whitespace or alphanumeric using regex
            line = re.sub(r'[^\w\s]','',line)
            words.extend(line.split())
    return words
clean_text('michelle_obama_speech.txt')
# Out:
# ['As',
#  'you',
#  'might',
#  'imagine',
#  'for',
#  'Barack',
#  'running',
#  'for',
#  'president',
#  'is',
#  'nothing',
#  'compared',
#  'to',
#  'that',
#  'first',
#  'game',
#  'of',
#  'basketball',
#  'with',
#  'my',
#  'brother',
#  'Craig',
#  'I',
#  'cant',
#  'tell',
#  'you',
#  'how',
#  'much',
#  'it',
#  'means',
#  'to',
#  'have',
#  'Craig',
#  'and',
#  'my',
#  'mom',
#  'here',
#  'tonight',
#  'Like',
#  'Craig',
#  'I',
#  'can',
#  'feel',
#  'my',
#  'dad',
#  'looking',
#  'down',
#  'on',
#  'us',
#  'just',
#  'as',
#  'Ive',
#  'felt',
#  'his',
#  'presence',
#  'in',
#  'every',
#  'gracefilled',
#  'moment',
#  'of',
#  'my',
#  'life',
#  'At',
#  '6foot6',
#  'Ive',
#  'often',
#  'felt',
#  'like',
#  'Craig',
#  'was',
#  'looking',
#  'down',
#  'on',
#  'me',
#  'too',
#  'literally',
#  'But',
#  'the',
#  'truth',
#  'is',
#  'both',
#  'when',
#  'we',
#  'were',
#  'kids',
#  'and',
#  'today',
#  'he',
#  'wasnt',
#  'looking',
#  'down',
#  'on',
#  'me',
#  'He',
#  'was',
#  'watching',
#  'over',
#  'me',
#  'And',
#  'hes',
#  'been',
#  'there',
#  'for',
#  'me',
#  'every',
#  'step',
#  'of',
#  'the',
#  'way',
#  'since',
#  'that',
#  'clear',
#  'February',
#  'day',
#  '19',
#  'months',
#  'ago',
#  'when',
#  'with',
#  'little',
#  'more',
#  'than',
#  'our',
#  'faith',
#  'in',
#  'each',
#  'other',
#  'and',
#  'a',
#  'hunger',
#  'for',
#  'change',
#  'we',
#  'joined',
#  'my',
#  'husband',
#  'Barack',
#  'Obama',
#  'on',
#  'the',
#  'improbable',
#  'journey',
#  'thats',
#  'brought',
#  'us',
#  'to',
#  'this',
#  'moment',
#  'But',
#  'each',
#  'of',
#  'us',
#  'also',
#  'comes',
#  'here',
#  'tonight',
#  'by',
#  'way',
#  'of',
#  'our',
#  'own',
#  'improbable',
#  'journey',
#  'I',
#  'come',
#  'here',
#  'tonight',
#  'as',
#  'a',
#  'sister',
#  'blessed',
#  'with',
#  'a',
#  'brother',
#  'who',
#  'is',
#  'my',
#  'mentor',
#  'my',
#  'protector',
#  'and',
#  'my',
#  'lifelong',
#  'friend',
#  'I',
#  'come',
#  'here',
#  'as',
#  'a',
#  'wife',
#  'who',
#  'loves',
#  'my',
#  'husband',
#  'and',
#  'believes',
#  'he',
#  'will',
#  'be',
#  'an',
#  'extraordinary',
#  'president',
#  'I',
#  'come',
#  'here',
#  'as',
#  'a',
#  'mom',
#  'whose',
#  'girls',
#  'are',
#  'the',
#  'heart',
#  'of',
#  'my',
#  'heart',
#  'and',
#  'the',
#  'center',
#  'of',
#  'my',
#  'world',
#  'theyre',
#  'the',
#  'first',
#  'thing',
#  'I',
#  'think',
#  'about',
#  'when',
#  'I',
#  'wake',
#  'up',
#  'in',
#  'the',
#  'morning',
#  'and',
#  'the',
#  'last',
#  'thing',
#  'I',
#  'think',
#  'about',
#  'when',
#  'I',
#  'go',
#  'to',
#  'bed',
#  'at',
#  'night',
#  'Their',
#  'future',
#  'and',
#  'all',
#  'our',
#  'childrens',
#  'future',
#  'is',
#  'my',
#  'stake',
#  'in',
#  'this',
#  'election',
#  'And',
#  'I',
#  'come',
#  'here',
#  'as',
#  'a',
#  'daughter',
#  'raised',
#  'on',
#  'the',
#  'South',
#  'Side',
#  'of',
#  'Chicago',
#  'by',
#  'a',
#  'father',
#  'who',
#  'was',
#  'a',
#  'bluecollar',
#  'city',
#  'worker',
#  'and',
#  'a',
#  'mother',
#  'who',
#  'stayed',
#  'at',
#  'home',
#  'with',
#  'my',
#  'brother',
#  'and',
#  'me',
#  'My',
#  'mothers',
#  'love',
#  'has',
#  'always',
#  'been',
#  'a',
#  'sustaining',
#  'force',
#  'for',
#  'our',
#  'family',
#  'and',
#  'one',
#  'of',
#  'my',
#  'greatest',
#  'joys',
#  'is',
#  'seeing',
#  'her',
#  'integrity',
#  'her',
#  'compassion',
#  'and',
#  'her',
#  'intelligence',
#  'reflected',
#  'in',
#  'my',
#  'own',
#  'daughters',
#  'My',
#  'dad',
#  'was',
#  'our',
#  'rock',
#  'Although',
#  'he',
#  'was',
#  'diagnosed',
#  'with',
#  'multiple',
#  'sclerosis',
#  'in',
#  'his',
#  'early',
#  '30s',
#  'he',
#  'was',
#  'our',
#  'provider',
#  'our',
#  'champion',
#  'our',
#  'hero',
#  'As',
#  'he',
#  'got',
#  'sicker',
#  'it',
#  'got',
#  'harder',
#  'for',
#  'him',
#  'to',
#  'walk',
#  'it',
#  'took',
#  'him',
#  'longer',
#  'to',
#  'get',
#  'dressed',
#  'in',
#  'the',
#  'morning',
#  'But',
#  'if',
#  'he',
#  'was',
#  'in',
#  'pain',
#  'he',
#  'never',
#  'let',
#  'on',
#  'He',
#  'never',
#  'stopped',
#  'smiling',
#  'and',
#  'laughing',
#  'even',
#  'while',
#  'struggling',
#  'to',
#  'button',
#  'his',
#  'shirt',
#  'even',
#  'while',
#  'using',
#  'two',
#  'canes',
#  'to',
#  'get',
#  'himself',
#  'across',
#  'the',
#  'room',
#  'to',
#  'give',
#  'my',
#  'mom',
#  'a',
#  'kiss',
#  'He',
#  'just',
#  'woke',
#  'up',
#  'a',
#  'little',
#  'earlier',
#  'and',
#  'worked',
#  'a',
#  'little',
#  'harder',
#  'He',
#  'and',
#  'my',
#  'mom',
#  'poured',
#  'everything',
#  'they',
#  'had',
#  'into',
#  'me',
#  'and',
#  'Craig',
#  'It',
#  'was',
#  'the',
#  'greatest',
#  'gift',
#  'a',
#  'child',
#  'can',
#  'receive',
#  'never',
#  'doubting',
#  'for',
#  'a',
#  'single',
#  'minute',
#  'that',
#  'youre',
#  'loved',
#  'and',
#  'cherished',
#  'and',
#  'have',
#  'a',
#  'place',
#  'in',
#  'this',
#  'world',
#  'And',
#  'thanks',
#  'to',
#  'their',
#  'faith',
#  'and',
#  'hard',
#  'work',
#  'we',
#  'both',
#  'were',
#  'able',
#  'to',
#  'go',
#  'on',
#  'to',
#  'college',
#  'So',
#  'I',
#  'know',
#  'firsthand',
#  'from',
#  'their',
#  'lives',
#  'and',
#  'mine',
#  'that',
#  'the',
#  'American',
#  'dream',
#  'endures',
#  'And',
#  'you',
#  'know',
#  'what',
#  'struck',
#  'me',
#  'when',
#  'I',
#  'first',
#  'met',
#  'Barack',
#  'was',
#  'that',
#  'even',
#  'though',
#  'he',
#  'had',
#  'this',
#  'funny',
#  'name',
#  'even',
#  'though',
#  'hed',
#  'grown',
#  'up',
#  'all',
#  'the',
#  'way',
#  'across',
#  'the',
#  'continent',
#  'in',
#  'Hawaii',
#  'his',
#  'family',
#  'was',
#  'so',
#  'much',
#  'like',
#  'mine',
#  'He',
#  'was',
#  'raised',
#  'by',
#  'grandparents',
#  'who',
#  'were',
#  'workingclass',
#  'folks',
#  'just',
#  'like',
#  'my',
#  'parents',
#  'and',
#  'by',
#  'a',
#  'single',
#  'mother',
#  'who',
#  'struggled',
#  'to',
#  'pay',
#  'the',
#  'bills',
#  'just',
#  'like',
#  'we',
#  'did',
#  'Like',
#  'my',
#  'family',
#  'they',
#  'scrimped',
#  'and',
#  'saved',
#  'so',
#  'that',
#  'he',
#  'could',
#  'have',
#  'opportunities',
#  'they',
#  'never',
#  'had',
#  'themselves',
#  'And',
#  'Barack',
#  'and',
#  'I',
#  'were',
#  'raised',
#  'with',
#  'so',
#  'many',
#  'of',
#  'the',
#  'same',
#  'values',
#  'that',
#  'you',
#  'work',
#  'hard',
#  'for',
#  'what',
#  'you',
#  'want',
#  'in',
#  'life',
#  'that',
#  'your',
#  'word',
#  'is',
#  'your',
#  'bond',
#  'and',
#  'you',
#  'do',
#  'what',
#  'you',
#  'say',
#  'youre',
#  'going',
#  'to',
#  'do',
#  'that',
#  'you',
#  'treat',
#  'people',
#  'with',
#  'dignity',
#  'and',
#  'respect',
#  'even',
#  'if',
#  'you',
#  'dont',
#  'know',
#  'them',
#  'and',
#  'even',
#  'if',
#  'you',
#  'dont',
#  'agree',
#  'with',
#  'them',
#  'And',
#  'Barack',
#  'and',
#  'I',
#  'set',
#  'out',
#  'to',
#  'build',
#  'lives',
#  'guided',
#  'by',
#  'these',
#  'values',
#  'and',
#  'pass',
#  'them',
#  'on',
#  'to',
#  'the',
#  'next',
#  'generation',
#  'Because',
#  'we',
#  'want',
#  'our',
#  'children',
#  'and',
#  'all',
#  'children',
#  'in',
#  'this',
#  'nation',
#  'to',
#  'know',
#  'that',
#  'the',
#  'only',
#  'limit',
#  'to',
#  'the',
#  'height',
#  'of',
#  'your',
#  'achievements',
#  'is',
#  'the',
#  'reach',
#  'of',
#  'your',
#  'dreams',
#  'and',
#  'your',
#  'willingness',
#  'to',
#  'work',
#  'for',
#  'them',
#  'And',
#  'as',
#  'our',
#  'friendship',
#  'grew',
#  'and',
#  'I',
#  'learned',
#  'more',
#  'about',
#  'Barack',
#  'he',
#  'introduced',
#  'me',
#  'to',
#  'the',
#  'work',
#  'hed',
#  'done',
#  'when',
#  'he',
#  'first',
#  'moved',
#  'to',
#  'Chicago',
#  'after',
#  'college',
#  'Instead',
#  'of',
#  'heading',
#  'to',
#  'Wall',
#  'Street',
#  'Barack',
#  'had',
#  'gone',
#  'to',
#  'work',
#  'in',
#  'neighborhoods',
#  'devastated',
#  'when',
#  'steel',
#  'plants',
#  'shut',
#  'down',
#  'and',
#  'jobs',
#  'dried',
#  'up',
#  'And',
#  'hed',
#  'been',
#  'invited',
#  'back',
#  'to',
#  'speak',
#  'to',
#  'people',
#  'from',
#  'those',
#  'neighborhoods',
#  'about',
#  'how',
#  'to',
#  'rebuild',
#  'their',
#  'community',
#  'The',
#  'people',
#  'gathered',
#  'together',
#  'that',
#  'day',
#  'were',
#  'ordinary',
#  'folks',
#  'doing',
#  'the',
#  'best',
#  'they',
#  'could',
#  'to',
#  'build',
#  'a',
#  'good',
#  'life',
#  'They',
#  'were',
#  'parents',
#  'living',
#  'paycheck',
#  'to',
#  'paycheck',
#  'grandparents',
#  'trying',
#  'to',
#  'get',
#  'by',
#  'on',
#  'a',
#  'fixed',
#  'income',
#  'men',
#  'frustrated',
#  'that',
#  'they',
#  'couldnt',
#  'support',
#  'their',
#  'families',
#  'after',
#  'their',
#  'jobs',
#  'disappeared',
#  'Those',
#  'folks',
#  'werent',
#  'asking',
#  'for',
#  'a',
#  'handout',
#  'or',
#  'a',
#  'shortcut',
#  'They',
#  'were',
#  'ready',
#  'to',
#  'work',
#  'they',
#  'wanted',
#  'to',
#  'contribute',
#  'They',
#  'believed',
#  'like',
#  'you',
#  'and',
#  'I',
#  'believe',
#  'that',
#  'America',
#  'should',
#  'be',
#  'a',
#  'place',
#  'where',
#  'you',
#  'can',
#  'make',
#  'it',
#  'if',
#  'you',
#  'try',
#  'Barack',
#  'stood',
#  'up',
#  'that',
#  'day',
#  'and',
#  'spoke',
#  'words',
#  'that',
#  'have',
#  'stayed',
#  'with',
#  'me',
#  'ever',
#  'since',
#  'He',
#  'talked',
#  'about',
#  'The',
#  'world',
#  'as',
#  'it',
#  'is',
#  'and',
#  'The',
#  'world',
#  'as',
#  'it',
#  'should',
#  'be',
#  'And',
#  'he',
#  'said',
#  'that',
#  'all',
#  'too',
#  'often',
#  'we',
#  'accept',
#  'the',
#  'distance',
#  'between',
#  'the',
#  'two',
#  'and',
#  'settle',
#  'for',
#  'the',
#  'world',
#  'as',
#  'it',
#  'is',
#  'even',
#  'when',
#  'it',
#  'doesnt',
#  'reflect',
#  'our',
#  'values',
#  'and',
#  'aspirations',
#  'But',
#  'he',
#  'reminded',
#  'us',
#  'that',
#  'we',
#  'know',
#  'what',
#  'our',
#  'world',
#  'should',
#  'look',
#  'like',
#  'We',
#  'know',
#  'what',
#  'fairness',
#  'and',
#  'justice',
#  'and',
#  'opportunity',
#  'look',
#  'like',
#  'And',
#  'he',
#  'urged',
#  'us',
#  'to',
#  'believe',
#  'in',
#  'ourselves',
#  'to',
#  'find',
#  'the',
#  'strength',
#  'within',
#  'ourselves',
#  'to',
#  'strive',
#  'for',
#  'the',
#  'world',
#  'as',
#  'it',
#  'should',
#  'be',
#  'And',
#  'isnt',
#  'that',
#  'the',
#  'great',
#  'American',
#  'story',
#  'Its',
#  'the',
#  'story',
#  'of',
#  'men',
#  'and',
#  'women',
#  'gathered',
#  'in',
#  'churches',
#  'and',
#  'union',
#  'halls',
#  'in',
#  'town',
#  'squares',
#  'and',
#  'high',
#  'school',
#  'gyms',
#  'people',
#  'who',
#  'stood',
#  'up',
#  'and',
#  'marched',
#  'and',
#  'risked',
#  'everything',
#  'they',
#  'had',
#  ...]

# %%
from stop_words import stop_words
def remove_stop_words(list):
    return [word for word in list if word.lower() not in stop_words]
remove_stop_words(clean_text('michelle_obama_speech.txt'))
def check_text_similarity(list_one,list_two):
    res = [x for x in (list_one + list_two) if x in list_one and x in list_two]
    similar_words_percent = (len(res)/(len(list_one) + len(list_two))) * 100
    return similar_words_percent
check_text_similarity(['apple','banana','mango','pawpaw'],['apple','mango','pear'])
# combining the function for a big one: biggest I have tried so far:
def comparing_text_in_file_similarity(file_one,file_two):
    file_one_words = remove_stop_words(clean_text(file_one))
    file_two_words = remove_stop_words(clean_text(file_two))
    return check_text_similarity(file_one_words,file_two_words)

comparing_text_in_file_similarity('michelle_obama_speech.txt','melina_trump_speech.txt')

# %%
#Find the 10 most repeated words in the romeo_and_juliet.txt

print(f'Juliet and Romoe must repeated words')
print(find_most_common_words('romeo_and_juliet.txt', 10))
print()
# Out:
# Juliet and Romoe must repeated words
# [(766, 'the'), (583, 'I'), (555, 'and'), (533, 'to'), (487, 'of'), (460, 'a'), (341, 'in'), (334, 'is'), (318, 'you'), (310, 'my')]

# %%
#Read the hacker news csv file and find out: a) Count the number of lines containing python or Python b) Count the number lines containing JavaScript,
#javascript or Javascript c) Count the number lines containing Java and not JavaScript

with open('hacker_news.csv',newline='') as f:
    csv_reader = csv.reader(f,delimiter=',')
    python_rows = 0
    javascript_rows = 0
    java_rows = 0
    for row in csv_reader:
        for i in range(len(row)):
            if re.findall(r'[Pp]ython',row[i]):
                python_rows += 1
            elif re.findall(r'[Jj]ava[Ss]cript',row[i]):
                javascript_rows +=1
            elif re.findall(r'Java$',row[i]):
                java_rows +=1
print(f'the number of lines containing a,b and c respectively are: {python_rows}, {javascript_rows} and {java_rows}')
from collections import Counter
with open('donald_speech.txt') as f:
    lines = f.readlines()
    words = []
    for line in lines:
        # removing all characters that are not whitespace or alphanumeric using regex, don't want punctuation affecting count
        line = re.sub(r'[^\w\s]','',line)
        words.extend(line.split())
Count = Counter(words)
Count.most_common(5)
# Out:
# the number of lines containing a,b and c respectively are: 266, 238 and 7
# [('the', 61), ('and', 53), ('will', 40), ('of', 38), ('to', 32)]
